# %%
num1 = int(input("Enter first number: "))
num2 = int(input("Enter second number: "))

a = num1
b = num2

# Find GCD
while b != 0:
    remainder = a % b
    a = b
    b = remainder

gcd = a

# Find LCM
lcm = (num1 * num2) // gcd

print("LCM:", lcm)
# Out:
# LCM: 132
