# %%
income= int(input("Enter your income"))

if income <= 12570:
    tax=0
elif income >= 12570:
    tax=(income-12570)*  0.20
else:
    tax=(income-12570) +(income-12570)*  0.20
print ("The tax should be" ,tax)
# Out:
# The tax should be 1486.0
